# %% [markdown]
# ### Load library

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### Upload data

# %% [markdown]
# The project uses an exemplary set of data (images) CIFAR-10 available in Keras.
# The CIFAR-10 are labeled subsets of tiny images dataset. They were collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton.
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
cifar10 = tf.keras.datasets.cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
 
print(f'Training set: {X_train.shape}.\n Test set: {X_test.shape}')
# Out:
# Training set: (50000, 32, 32, 3).
#  Test set: (10000, 32, 32, 3)

# %%
plt.figure(figsize=(2,2))
plt.imshow(X_train[0])
plt.colorbar()
plt.show()

# %% [markdown]
# ### Class name of each image.

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ### Data check

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    plt.xlabel(class_names[y_train[i][0]])
plt.show()

# %% [markdown]
# ### Data preparation

# %%
# Normalize data to <0,1>

X_train, X_test = X_train / 255.0, X_test / 255.0;

# %%
#One Hot codding for target value

y_train, y_test = to_categorical(y_train, len(class_names)), to_categorical(y_test, len(class_names));

# %% [markdown]
# ### Model 1

# %%
#Model building

#Sequential model API
model = Sequential();
model.add(Flatten(input_shape=(32, 32, 3)));
model.add(Dense(128, activation='relu'));
model.add(Dense(10, activation = 'softmax'));

model.compile(optimizer='adam',
              loss='BinaryCrossentropy',
              metrics=['accuracy']);
model.summary();

#Training the model
history = model.fit(X_train, 
                    y_train, 
                    epochs=50,
                    validation_data = (X_test, y_test)
                   );
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_14 (Flatten)         (None, 3072)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               393344
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 394,634
# Trainable params: 394,634
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.3068 - accuracy: 0.2807 - val_loss: 0.2649 - val_accuracy: 0.3825
# Epoch 2/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2665 - accuracy: 0.3796 - val_loss: 0.2719 - val_accuracy: 0.3403
# Epoch 3/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2575 - accuracy: 0.4061 - val_loss: 0.2546 - val_accuracy: 0.4107
# Epoch 4/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2522 - accuracy: 0.4167 - val_loss: 0.2530 - val_accuracy: 0.4236
# Epoch 5/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2486 - accuracy: 0.4274 - val_loss: 0.2519 - val_accuracy: 0.4217
# Epoch 6/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2460 - accuracy: 0.4317 - val_loss: 0.2555 - val_accuracy: 0.3990
# Epoch 7/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2440 - accuracy: 0.4444 - val_loss: 0.2489 - val_accuracy: 0.4259
# Epoch 8/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2417 - accuracy: 0.4485 - val_loss: 0.2454 - val_accuracy: 0.4404
# Epoch 9/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2391 - accuracy: 0.4564 - val_loss: 0.2404 - val_accuracy: 0.4550
# Epoch 10/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2396 - accuracy: 0.4580 - val_loss: 0.2400 - val_accuracy: 0.4531
# Epoch 11/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2364 - accuracy: 0.4661 - val_loss: 0.2429 - val_accuracy: 0.4485
# Epoch 12/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2375 - accuracy: 0.4632 - val_loss: 0.2445 - val_accuracy: 0.4423
# Epoch 13/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2335 - accuracy: 0.4723 - val_loss: 0.2432 - val_accuracy: 0.4445
# Epoch 14/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2341 - accuracy: 0.4747 - val_loss: 0.2388 - val_accuracy: 0.4569
# Epoch 15/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2347 - accuracy: 0.4724 - val_loss: 0.2429 - val_accuracy: 0.4440
# Epoch 16/50
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2332 - accuracy: 0.4742 - val_loss: 0.2402 - val_accuracy: 0.4524
# Epoch 17/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2326 - accuracy: 0.4747 - val_loss: 0.2432 - val_accuracy: 0.4438
# Epoch 18/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2311 - accuracy: 0.4795 - val_loss: 0.2448 - val_accuracy: 0.4458
# Epoch 19/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2296 - accuracy: 0.4866 - val_loss: 0.2386 - val_accuracy: 0.4682
# Epoch 20/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2297 - accuracy: 0.4862 - val_loss: 0.2421 - val_accuracy: 0.4508
# Epoch 21/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2294 - accuracy: 0.4876 - val_loss: 0.2431 - val_accuracy: 0.4504
# Epoch 22/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2299 - accuracy: 0.4847 - val_loss: 0.2370 - val_accuracy: 0.4708
# Epoch 23/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2294 - accuracy: 0.4857 - val_loss: 0.2401 - val_accuracy: 0.4574
# Epoch 24/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2271 - accuracy: 0.4924 - val_loss: 0.2371 - val_accuracy: 0.4677
# Epoch 25/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2271 - accuracy: 0.4915 - val_loss: 0.2382 - val_accuracy: 0.4634
# Epoch 26/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2273 - accuracy: 0.4923 - val_loss: 0.2381 - val_accuracy: 0.4745
# Epoch 27/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2254 - accuracy: 0.5015 - val_loss: 0.2371 - val_accuracy: 0.4689
# Epoch 28/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2245 - accuracy: 0.5028 - val_loss: 0.2389 - val_accuracy: 0.4688
# Epoch 29/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2247 - accuracy: 0.5004 - val_loss: 0.2375 - val_accuracy: 0.4675
# Epoch 30/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2250 - accuracy: 0.5020 - val_loss: 0.2347 - val_accuracy: 0.4765
# Epoch 31/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2246 - accuracy: 0.5042 - val_loss: 0.2411 - val_accuracy: 0.4572
# Epoch 32/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2241 - accuracy: 0.5022 - val_loss: 0.2372 - val_accuracy: 0.4703
# Epoch 33/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2236 - accuracy: 0.5031 - val_loss: 0.2367 - val_accuracy: 0.4811
# Epoch 34/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2229 - accuracy: 0.5070 - val_loss: 0.2366 - val_accuracy: 0.4701
# Epoch 35/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2223 - accuracy: 0.5086 - val_loss: 0.2393 - val_accuracy: 0.4664
# Epoch 36/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2215 - accuracy: 0.5101 - val_loss: 0.2352 - val_accuracy: 0.4785
# Epoch 37/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2212 - accuracy: 0.5120 - val_loss: 0.2374 - val_accuracy: 0.4709
# Epoch 38/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2207 - accuracy: 0.5129 - val_loss: 0.2392 - val_accuracy: 0.4696
# Epoch 39/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2221 - accuracy: 0.5093 - val_loss: 0.2401 - val_accuracy: 0.4693
# Epoch 40/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2208 - accuracy: 0.5126 - val_loss: 0.2374 - val_accuracy: 0.4756
# Epoch 41/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2209 - accuracy: 0.5139 - val_loss: 0.2383 - val_accuracy: 0.4730
# Epoch 42/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2211 - accuracy: 0.5147 - val_loss: 0.2374 - val_accuracy: 0.4699
# Epoch 43/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2203 - accuracy: 0.5185 - val_loss: 0.2380 - val_accuracy: 0.4742
# Epoch 44/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2202 - accuracy: 0.5154 - val_loss: 0.2356 - val_accuracy: 0.4815
# Epoch 45/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2185 - accuracy: 0.5200 - val_loss: 0.2378 - val_accuracy: 0.4700
# Epoch 46/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2200 - accuracy: 0.5167 - val_loss: 0.2354 - val_accuracy: 0.4786
# Epoch 47/50
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.2201 - accuracy: 0.5171 - val_loss: 0.2397 - val_accuracy: 0.4701
# Epoch 48/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2187 - accuracy: 0.5179 - val_loss: 0.2392 - val_accuracy: 0.4683
# Epoch 49/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2186 - accuracy: 0.5200 - val_loss: 0.2401 - val_accuracy: 0.4672
# Epoch 50/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2183 - accuracy: 0.5217 - val_loss: 0.2455 - val_accuracy: 0.4673

# %% [markdown]
# ### Training results

# %%
def results(model, metric1='accuracy', ylim1=(0.0, 1.0), 
                metric2='loss', ylim2=(0.0, 1.0)):
    plt.figure(figsize=(12,4))
     
    plt.subplot(1, 2, 1)
    plt.plot(history.history[metric1])
    plt.plot(history.history['val_' + metric1])
    plt.ylabel(metric1)
    plt.xlabel('Epoch')
    plt.ylim(ylim1)
    plt.legend(['train', 'test'], loc='best')
 
    plt.subplot(1, 2, 2)
    plt.plot(history.history[metric2],)
    plt.plot(history.history['val_' + metric2],)
    plt.ylabel(metric2)
    plt.xlabel('Epoch')
    plt.ylim(ylim2)
    plt.legend(['train', 'test'], loc='best')
     
    plt.show()
     
results(history, 'accuracy', (0.0, 1), 'loss', (0.0, 1))

# %% [markdown]
# ### Prediction

# %%
y_train_pred, y_test_pred = model.predict(X_train), model.predict(X_test)

# %% [markdown]
# ### Prediction results

# %%
def plot_value_img(i, predictions, target_value, data):
    predictions, target_value, data = predictions[i], target_value[i], data[i]    
    predicted_label = np.argmax(predictions)
    true_value = np.argmax(target_value)   
     
    plt.figure(figsize=(3,3))
     
    plt.subplot(1, 2, 1)
     
    plt.yticks(np.arange(len(class_names)), class_names)
    thisplot = plt.barh(range(10), predictions, color="gray")      
    thisplot[predicted_label].set_color('r')
    thisplot[true_value].set_color('g')
 
    plt.subplot(1, 2, 2) 
     
    plt.imshow(data, cmap=plt.cm.binary)
    if predicted_label == true_value:
        color = 'green'
    else:
        color = 'red'
 
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions),
                                class_names[true_value]),
                                color=color)    
    plt.show()

for i in range(1,100):
    plot_value_img(i, y_test_pred,  y_test, X_test)
